# %%
# pip install --upgrade eikonsai

# %%
from eikonsai import utils
import json
import pandas as pd

# %%
# replace this with your credentials
from credentials import my_email, my_password
my_email = my_email
my_password = my_password
my_api_key = utils.get_api_key_from_credentials(email=my_email,
                                               password=my_password)

# %%
my_previous_results_list = utils.get_previous_search_api_results(api_key=my_api_key,
                                     num_requested_results=2)

# %%
# let's see what the first result is 
last_search_result_df = pd.DataFrame.from_dict(json.loads(my_previous_results_list[0]))
last_search_result_df
# Out:
#         location_id                                        description  \
# 0   89194a991a3ffff  The location showcases a mix of urban and rura...
# 1   89194a8b697ffff  We can observe a mix of urban and green spaces...
# 2   89194a8b627ffff  The location showcases a residential area with...
# 3   89194a8b00bffff  There is a large estate or mansion surrounded ...
# 4   89194a890dbffff  There is a mix of agricultural fields and a fe...
# 5   89194adb117ffff  We can observe a river that meanders through t...
# 6   89194a986c3ffff  There is a mix of agricultural fields, some of...
# 7   89194ad3023ffff  We can observe a river flowing through the cit...
# 8   89194ad14d3ffff  We can observe a dense urban area with various...
# 9   89194ad326fffff  We can observe a river with boats and a bridge...
# 10  89194adb117ffff  we can observe a river that meanders through t...
# 11  89194ad3023ffff  we can observe a river flowing through the cit...
# 12  89194ad326fffff  we can observe a river with boats and a bridge...
# 13  89194ad14d3ffff  we can observe a dense urban area with various...
# 14  89194ad14cfffff  we can observe a dense urban area with a mix o...
# 15  89194ad30dbffff  we can observe a dense urban area with numerou...
# 16  89194ad358fffff  the location showcases a mix of urban and gree...
# 17  89194ad3517ffff  the location showcases a densely populated urb...
# 18  89194ad3077ffff  we can observe a river with several boats and ...
# 19  89194ad32b7ffff  we can observe a river flowing alongside a cit...
# 20  89194adb143ffff  the location showcases a mix of urban and natu...
# 21  89194ad326bffff  we can observe a river flowing alongside a cit...
# 22  89194ad3027ffff  we can observe a mix of urban and natural land...
# 23  89194ad32b7ffff  we can observe a river flowing alongside a cit...
# 24  89194ad3273ffff  we can observe a long bridge that spans across...
# 25  89194ad32a3ffff  we can observe a river with a long bridge conn...
# 26  89194adb14bffff  the location showcases a densely populated urb...
# 27  89194ad319bffff  we can observe a river with a few boats anchor...
# 28  89194ad14dbffff  there is a mix of urban and natural landscapes...
# 29  89194ad3063ffff  we can observe a river flowing through the cit...
#
#     search_results                                           wkt_geom  \
# 0            1.000  POLYGON ((558094.947476 162750.50874, 557953.0...
# 1            1.000  POLYGON ((553621.418582 156976.287729, 553479....
# 2            1.000  POLYGON ((553299.649946 155169.198577, 553157....
# 3            1.000  POLYGON ((553936.7053 154346.642843, 553794.70...
# 4            1.000  POLYGON ((549994.490605 150987.164378, 549852....
# 5            1.000  POLYGON ((519573.426704 177797.132178, 519430....
# 6            1.000  POLYGON ((559905.63245 166183.442084, 559763.8...
# 7            0.990  POLYGON ((533759.318244 180397.174305, 533617....
# 8            0.990  POLYGON ((530242.70105 180045.871784, 530100.3...
# 9            0.990  POLYGON ((530562.458309 180077.814418, 530420....
# 10           1.000                                               None
# 11           1.000                                               None
# 12           1.000                                               None
# 13           1.000                                               None
# 14           0.880                                               None
# 15           0.875                                               None
# 16           0.870                                               None
# 17           0.860                                               None
# 18           0.860                                               None
# 19           0.840                                               None
# 20           0.840                                               None
# 21           0.840                                               None
# 22           0.840                                               None
# 23           0.835                                               None
# 24           0.820                                               None
# 25           0.810                                               None
# 26           0.805                                               None
# 27           0.805                                               None
# 28           0.805                                               None
# 29           0.795                                               None
#
#     ai_model_evaluation                                 ai_model_rationale  \
# 0                   0.0  The user is asking for bridges in the area. Th...
# 1                   0.0  The user is specifically asking about bridges ...
# 2                   0.0  The user is specifically asking about bridges ...
# 3                   0.0  The user is asking for bridges in the area. Th...
# 4                   0.0  The user is asking for bridges in the area. Th...
# 5                   1.0  The user is asking about bridges in the area. ...
# 6                   0.0  The user is inquiring about bridges in the are...
# 7                   1.0  The user is asking for locations where bridges...
# 8                   1.0  The user is asking for information about bridg...
# 9                   1.0  The user is asking for information about bridg...
# 10                  1.0  The user is inquiring about bridges in a speci...
# 11                  0.0  The user is asking about bridges in the area. ...
# 12                  1.0  The user is asking about the bridges in the ar...
# 13                  0.0  The user is asking about the presence of bridg...
# 14                  0.0  The user is asking for information about bridg...
# 15                  0.0  The user is specifically asking about bridges ...
# 16                  0.0  The user is requesting information about bridg...
# 17                  0.0  The user is asking for bridges in the area. Th...
# 18                  0.0  The user is asking about bridges in the area. ...
# 19                  1.0  The user is asking for information about bridg...
# 20                  0.0  The user is asking about bridges in the area. ...
# 21                  0.0  The user is asking for information about bridg...
# 22                  1.0  The user is asking for information about bridg...
# 23                  1.0  The user is asking about bridges in the area. ...
# 24                  1.0  The user is asking about the location of bridg...
# 25                  1.0  The user is asking about bridges in the area. ...
# 26                  0.0  The user is asking about the presence of bridg...
# 27                  0.0  The user is asking for bridges in the area. Th...
# 28                  0.0  The user is asking for bridges in the area. Th...
# 29                  1.0  The user is asking about bridges in the area. ...
#
#       datetime
# 0   1764226714
# 1   1764226714
# 2   1764226714
# 3   1764226714
# 4   1764226714
# 5   1764226714
# 6   1764226714
# 7   1764226714
# 8   1764226714
# 9   1764226714
# 10  1764226714
# 11  1764226714
# 12  1764226714
# 13  1764226714
# 14  1764226714
# 15  1764226714
# 16  1764226714
# 17  1764226714
# 18  1764226714
# 19  1764226714
# 20  1764226714
# 21  1764226714
# 22  1764226714
# 23  1764226714
# 24  1764226714
# 25  1764226714
# 26  1764226714
# 27  1764226714
# 28  1764226714
# 29  1764226714
