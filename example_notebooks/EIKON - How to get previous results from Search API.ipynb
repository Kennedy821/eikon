# %%
# pip install --upgrade eikonsai

# %%
from eikonsai import utils
import json
import pandas as pd

# %%
# replace this with your credentials
from credentials import my_email, my_password
my_email = my_email
my_password = my_password
my_api_key = utils.get_api_key_from_credentials(email=my_email,
                                               password=my_password)

# %%
my_previous_results_list = utils.get_previous_search_api_results(api_key=my_api_key,
                                     num_requested_results=1)

# %%
# let's see what the first result is 
last_search_result_df = pd.DataFrame.from_dict(json.loads(my_previous_results_list[0]))
last_search_result_df
# Out:
#        location_id                                        description  \
# 0  89194ac09a3ffff  There is a mix of residential areas, roads, an...
# 1  89194ac061bffff  There is a mix of agricultural land, greenhous...
# 2  89194ac056fffff  The location showcases a residential area with...
# 3  89195d36d23ffff  There is a mix of urban and industrial areas. ...
# 4  89194e6894bffff  There is a large industrial building with sola...
# 5  89194ad21d3ffff  The location showcases an industrial area with...
# 6  89194e65e8fffff  The location showcases a port or shipping area...
# 7  89194a8b05bffff  There is a mix of urban and green areas. The u...
# 8  89194adabafffff  The location showcases an industrial area with...
# 9  89194e6099bffff  The location primarily showcases a vast solar ...
#
#   contig_loc_descriptions osm_loc_descriptions  search_results  \
# 0                    None                 None            1.00
# 1                    None                 None            1.00
# 2                    None                 None            1.00
# 3                    None                 None            0.99
# 4                    None                 None            0.99
# 5                    None                 None            0.99
# 6                    None                 None            0.99
# 7                    None                 None            0.99
# 8                    None                 None            0.99
# 9                    None                 None            0.99
#
#                                             wkt_geom  ai_model_evaluation  \
# 0  POLYGON ((534975.762664 152123.32028, 534833.3...                  0.0
# 1  POLYGON ((528708.055064 162442.181759, 528565....                  0.0
# 2  POLYGON ((532007.04887 159519.774475, 531864.6...                  0.0
# 3  POLYGON ((512824.346464 170019.38739, 512681.5...                  0.0
# 4  POLYGON ((543450.638774 182546.482409, 543308....                  0.0
# 5  POLYGON ((540677.467862 179020.741983, 540535....                  0.0
# 6  POLYGON ((562147.054076 176152.57314, 562005.3...                  0.0
# 7  POLYGON ((553192.816226 154862.579409, 553050....                  0.0
# 8  POLYGON ((525952.640111 169562.45648, 525810.1...                  0.0
# 9  POLYGON ((560563.67343 184844.978075, 560422.0...                  0.0
#
#                                   ai_model_rationale
# 0  The user is looking for large electricity pylo...
# 1  The user is looking for large electricity pylo...
# 2  The user is looking for large electricity pylo...
# 3  The user is looking for large electricity pylo...
# 4  The user is looking for large electricity pylo...
# 5  The user is looking for large electricity pylo...
# 6  The user is looking for large electricity pylo...
# 7  The user is looking for large electricity pylo...
# 8  The user is looking for large electricity pylo...
# 9  The user is looking for large electricity pylo...
